# %% [markdown]
# # Prepare well-resolution TARGET2 CellProfiler features

# %%
import os
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

# Not used but needed for downloads from Broad S3
import pyarrow
import fsspec
import s3fs

# ignore mix type warnings from pandas
import warnings

warnings.filterwarnings("ignore")

# %%
def summarize_missing_values(df: pd.DataFrame) -> pd.DataFrame:
    """
    Summarize NaN, positive infinity, and negative infinity occurrences in a DataFrame.

    :param df: pandas DataFrame to summarize.
    :return: pandas DataFrame summarizing NaN, positive infinity, and negative infinity counts.
    """
    nan_counts = df.isna().sum().sum()
    pos_inf_counts = (df == np.inf).sum().sum()
    neg_inf_counts = (df == -np.inf).sum().sum()

    summary_df = pd.DataFrame({
        'NaN_count': [nan_counts],
        'Pos_inf_count': [pos_inf_counts],
        'Neg_inf_count': [neg_inf_counts]
    })

    return summary_df

def impute_source(source, df):
    df_source = df[df["Metadata_Source"] == source]

    # Separate numeric and non-numeric columns
    numeric_cols = df_source.select_dtypes(include=[np.number]).columns
    non_numeric_cols = df_source.select_dtypes(exclude=[np.number]).columns
    df_numeric = df_source[numeric_cols]
    df_non_numeric = df_source[non_numeric_cols]

    df_numeric = df_numeric.replace([np.inf, -np.inf], np.nan)

    imputer = KNNImputer()

    # doesn't actually update per-column because the imputer does full-df, but that'd be slower so we don't
    with tqdm(total=len(df_numeric), desc=f"Imputing Source: {source}") as pbar:
        imputed_data = imputer.fit_transform(df_numeric)
        pbar.update(len(df_numeric))

    df_imputed_numeric = pd.DataFrame(imputed_data, columns=numeric_cols)

    # Concatenate imputed numeric columns with non-numeric columns
    df_imputed = pd.concat([df_non_numeric.reset_index(drop=True), df_imputed_numeric.reset_index(drop=True)], axis=1)

    return df_imputed

# %%
plates = pd.read_csv("../metadata/plate.csv.gz")
wells = pd.read_csv("../metadata/well.csv.gz")
compounds = pd.read_csv("../metadata/compound.csv.gz")

# %%
profile_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/profiles/"
    "{Metadata_Batch}/{Metadata_Plate}/{Metadata_Plate}.parquet"
)

loaddata_formatter = (
    "s3://cellpainting-gallery/cpg0016-jump/"
    "{Metadata_Source}/workspace/load_data_csv/"
    "{Metadata_Batch}/{Metadata_Plate}/load_data_with_illum.parquet"
)

# %%
target2_plates = plates.query("Metadata_PlateType == 'TARGET2'")

# %%
target2_plates
# Out:
#      Metadata_Source               Metadata_Batch     Metadata_Plate  \
# 161        source_10  2021_08_03_U2OS_48_hr_run12  Dest210726-160150
# 180        source_10  2021_08_09_U2OS_48_hr_run13  Dest210727-153003
# 195        source_10  2021_08_12_U2OS_48_hr_run15  Dest210803-153958
# 213        source_10  2021_08_17_U2OS_48_hr_run16  Dest210809-134534
# 231        source_10  2021_08_20_U2OS_48_hr_run17  Dest210810-173723
# ...              ...                          ...                ...
# 2315        source_9               20210915-Run10         GR00003310
# 2324        source_9               20210918-Run11         GR00004371
# 2341        source_9               20211013-Run14         GR00003283
# 2354        source_9               20211102-Run15         GR00004395
# 2365        source_9               20211103-Run16         GR00004409
#
#      Metadata_PlateType
# 161             TARGET2
# 180             TARGET2
# 195             TARGET2
# 213             TARGET2
# 231             TARGET2
# ...                 ...
# 2315            TARGET2
# 2324            TARGET2
# 2341            TARGET2
# 2354            TARGET2
# 2365            TARGET2
#
# [141 rows x 4 columns]

# %% [markdown]
# ## Download well-resolution CellProfiler features for all TARGET2 plates

# %%
# %%time

try:
    target2_features = pd.read_parquet("../data/target2_wellres_features.parquet")
except:

    dframes = []
    columns = None # so we get all features

    def fetch_parquet(row):
        s3_path = profile_formatter.format(**row._asdict())
        return pd.read_parquet(s3_path, storage_options={"anon": True}, columns=columns)

    with ThreadPoolExecutor() as executor:
        dframes = list(tqdm(executor.map(fetch_parquet, target2_plates.itertuples(index=False)), total=len(target2_plates)))

    target2_features = pd.concat(dframes)
    target2_features.to_parquet("../data/target2_wellres_features.parquet")

target2_features
# Out:
#   0%|          | 0/141 [00:00<?, ?it/s]
# CPU times: user 1min 45s, sys: 28.2 s, total: 2min 13s
# Wall time: 1min 18s
#      Metadata_Source     Metadata_Plate Metadata_Well  Cells_AreaShape_Area  \
# 0          source_10  Dest210726-160150           A01                3846.4
# 1          source_10  Dest210726-160150           A02                3484.2
# 2          source_10  Dest210726-160150           A03                3281.9
# 3          source_10  Dest210726-160150           A04                3476.5
# 4          source_10  Dest210726-160150           A05                3592.1
# ...              ...                ...           ...                   ...
# 1531        source_9         GR00004409           Z44                2501.1
# 1532        source_9         GR00004409           Z45                2497.0
# 1533        source_9         GR00004409           Z46                2470.0
# 1534        source_9         GR00004409           Z47                2725.4
# 1535        source_9         GR00004409           Z48                2811.6
#
#       Cells_AreaShape_BoundingBoxArea  Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                              8135.6                                594.88
# 1                              7088.1                                541.40
# 2                              6740.3                                540.91
# 3                              7233.5                                554.90
# 4                              7581.8                                565.46
# ...                               ...                                   ...
# 1531                           4571.1                                560.30
# 1532                           4529.4                                555.90
# 1533                           4479.2                                548.36
# 1534                           5025.1                                553.86
# 1535                           5146.8                                528.91
#
#       Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                   544.30
# 1                                   539.61
# 2                                   564.09
# 3                                   491.65
# 4                                   555.42
# ...                                    ...
# 1531                                560.26
# 1532                                563.43
# 1533                                578.95
# 1534                                565.84
# 1535                                577.75
#
#       Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                   506.29
# 1                                   458.50
# 2                                   458.88
# 3                                   472.11
# 4                                   480.46
# ...                                    ...
# 1531                                493.83
# 1532                                491.44
# 1533                                482.96
# 1534                                485.54
# 1535                                458.83
#
#       Cells_AreaShape_BoundingBoxMinimum_Y  Cells_AreaShape_Center_X  ...  \
# 0                                   454.05                    550.31  ...
# 1                                   455.57                    499.72  ...
# 2                                   483.44                    498.92  ...
# 3                                   406.53                    512.92  ...
# 4                                   468.08                    522.43  ...
# ...                                    ...                       ...  ...
# 1531                                493.32                    526.64  ...
# 1532                                495.61                    523.31  ...
# 1533                                512.79                    515.18  ...
# 1534                                495.00                    519.22  ...
# 1535                                507.01                    493.26  ...
#
#       Nuclei_Texture_Variance_RNA_10_02_256  \
# 0                                    52.879
# 1                                    62.107
# 2                                    54.887
# 3                                    56.545
# 4                                    64.136
# ...                                     ...
# 1531                                 54.051
# 1532                                 52.398
# 1533                                 60.019
# 1534                                 52.872
# 1535                                 49.069
#
#       Nuclei_Texture_Variance_RNA_10_03_256  \
# 0                                    49.352
# 1                                    55.949
# 2                                    50.217
# 3                                    52.062
# 4                                    58.298
# ...                                     ...
# 1531                                 53.101
# 1532                                 50.418
# 1533                                 58.125
# 1534                                 51.857
# 1535                                 48.489
#
#       Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                                   50.861
# 1                                   59.508
# 2                                   52.887
# 3                                   56.238
# 4                                   62.002
# ...                                    ...
# 1531                                51.344
# 1532                                49.035
# 1533                                56.818
# 1534                                49.610
# 1535                                46.207
#
#       Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                   51.543
# 1                                   60.461
# 2                                   53.876
# 3                                   57.078
# 4                                   63.093
# ...                                    ...
# 1531                                51.742
# 1532                                49.288
# 1533                                57.189
# 1534                                49.757
# 1535                                46.536
#
#       Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                   50.538
# 1                                   59.221
# 2                                   52.707
# 3                                   55.913
# 4                                   61.794
# ...                                    ...
# 1531                                51.299
# 1532                                49.087
# 1533                                56.923
# 1534                                49.552
# 1535                                46.245
#
#       Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                   51.884
# 1                                   60.675
# 2                                   53.984
# 3                                   57.400
# 4                                   63.153
# ...                                    ...
# 1531                                51.507
# 1532                                49.531
# 1533                                57.286
# 1534                                50.035
# 1535                                46.579
#
#       Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                   52.263
# 1                                   61.428
# 2                                   54.283
# 3                                   57.872
# 4                                   63.637
# ...                                    ...
# 1531                                51.875
# 1532                                49.877
# 1533                                57.917
# 1534                                50.196
# 1535                                46.959
#
#       Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                   52.625
# 1                                   62.315
# 2                                   55.613
# 3                                   58.614
# 4                                   64.359
# ...                                    ...
# 1531                                53.164
# 1532                                51.324
# 1533                                59.310
# 1534                                51.243
# 1535                                48.079
#
#       Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                   52.144
# 1                                   61.100
# 2                                   54.511
# 3                                   57.834
# 4                                   63.523
# ...                                    ...
# 1531                                51.923
# 1532                                49.960
# 1533                                57.726
# 1534                                50.180
# 1535                                46.756
#
#       Nuclei_Texture_Variance_RNA_5_03_256
# 0                                   53.302
# 1                                   62.480
# 2                                   55.356
# 3                                   58.898
# 4                                   64.394
# ...                                    ...
# 1531                                52.834
# 1532                                51.313
# 1533                                59.307
# 1534                                51.654
# 1535                                48.111
#
# [64464 rows x 4765 columns]

# %% [markdown]
# ## Add batch info again

# %%
target2_features = target2_features.merge(
    target2_plates,
    left_on=["Metadata_Source", "Metadata_Plate"],
    right_on=["Metadata_Source", "Metadata_Plate"],
    how="left"
).drop("Metadata_PlateType", axis=1)

# %% [markdown]
# ### Impute missing

# %%
summarize_missing_values(target2_features)
# Out:
#    NaN_count  Pos_inf_count  Neg_inf_count
# 0       5261             33              0

# %%
# %%time

sources = target2_features["Metadata_Source"].unique()
imputed_dfs = []

# Using ThreadPoolExecutor for parallel processing
with ThreadPoolExecutor(max_workers=len(sources)) as executor:
    # Future to source mapping
    future_to_source = {executor.submit(impute_source, source, target2_features): source for source in sources}

    # Collecting results
    for future in as_completed(future_to_source):
        source = future_to_source[future]
        try:
            imputed_df = future.result()
            imputed_dfs.append(imputed_df)
        except Exception as e:
            print(f"Source {source} generated an exception: {e}")

target2_features_imputed = pd.concat(imputed_dfs, ignore_index=True)
# Out:
# Imputing Source: source_13:   0%|          | 0/2283 [00:00<?, ?it/s]
# Imputing Source: source_10:   0%|          | 0/2302 [00:00<?, ?it/s]
# Imputing Source: source_8:   0%|          | 0/1536 [00:00<?, ?it/s]
# Imputing Source: source_11:   0%|          | 0/2684 [00:00<?, ?it/s]
# Imputing Source: source_7:   0%|          | 0/2688 [00:00<?, ?it/s]
# Imputing Source: source_2:   0%|          | 0/3828 [00:00<?, ?it/s]
# Imputing Source: source_6:   0%|          | 0/8064 [00:00<?, ?it/s]
# Imputing Source: source_3:   0%|          | 0/9599 [00:00<?, ?it/s]
# Imputing Source: source_4:   0%|          | 0/8442 [00:00<?, ?it/s]
# Imputing Source: source_5:   0%|          | 0/9214 [00:00<?, ?it/s]
# Imputing Source: source_9:   0%|          | 0/13824 [00:00<?, ?it/s]
# CPU times: user 3min 9s, sys: 10.1 s, total: 3min 19s
# Wall time: 1min 33s

# %%
summarize_missing_values(target2_features_imputed)
# Out:
#    NaN_count  Pos_inf_count  Neg_inf_count
# 0          0              0              0

# %%
target2_features_imputed
# Out:
#       Metadata_Source Metadata_Plate Metadata_Well Metadata_Batch  \
# 0            source_8       A1170384           A01             J1
# 1            source_8       A1170384           A02             J1
# 2            source_8       A1170384           A03             J1
# 3            source_8       A1170384           A04             J1
# 4            source_8       A1170384           A05             J1
# ...               ...            ...           ...            ...
# 64459       source_13   CP-CC9-R7-29           P20  20221120_Run6
# 64460       source_13   CP-CC9-R7-29           P21  20221120_Run6
# 64461       source_13   CP-CC9-R7-29           P22  20221120_Run6
# 64462       source_13   CP-CC9-R7-29           P23  20221120_Run6
# 64463       source_13   CP-CC9-R7-29           P24  20221120_Run6
#
#        Cells_AreaShape_Area  Cells_AreaShape_BoundingBoxArea  \
# 0               3683.200000                      7920.000000
# 1               3519.000000                      7427.500000
# 2               3551.500000                      7493.600000
# 3               3494.400000                      7360.200000
# 4               3625.800000                      7620.300000
# ...                     ...                              ...
# 64459           2735.141361                      5259.052356
# 64460           2492.848859                      4878.090779
# 64461           2701.863939                      5179.042455
# 64462           2755.432136                      5216.364957
# 64463           3092.713193                      5983.594328
#
#        Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                                570.710000
# 1                                574.880000
# 2                                548.580000
# 3                                561.720000
# 4                                552.490000
# ...                                     ...
# 64459                            679.311932
# 64460                            647.097909
# 64461                            653.885934
# 64462                            646.266520
# 64463                            667.466858
#
#        Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                565.870000
# 1                                586.630000
# 2                                547.250000
# 3                                580.460000
# 4                                576.340000
# ...                                     ...
# 64459                            572.702122
# 64460                            524.178232
# 64461                            579.227366
# 64462                            572.009049
# 64463                            583.646272
#
#        Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                482.460000
# 1                                488.560000
# 2                                463.350000
# 3                                477.120000
# 4                                466.990000
# ...                                     ...
# 64459                            608.692202
# 64460                            578.300856
# 64461                            584.200512
# 64462                            576.276940
# 64463                            591.395793
#
#        Cells_AreaShape_BoundingBoxMinimum_Y  ...  \
# 0                                478.170000  ...
# 1                                502.490000  ...
# 2                                461.680000  ...
# 3                                494.980000  ...
# 4                                489.870000  ...
# ...                                     ...  ...
# 64459                            502.787820  ...
# 64460                            458.030418  ...
# 64461                            509.318159  ...
# 64462                            501.680011  ...
# 64463                            509.997451  ...
#
#        Nuclei_Texture_Variance_RNA_10_02_256  \
# 0                                 346.150000
# 1                                 339.000000
# 2                                 376.540000
# 3                                 374.860000
# 4                                 389.630000
# ...                                      ...
# 64459                               7.437796
# 64460                               7.030951
# 64461                               7.896472
# 64462                               5.636992
# 64463                               6.756054
#
#        Nuclei_Texture_Variance_RNA_10_03_256  \
# 0                                 332.330000
# 1                                 322.480000
# 2                                 358.890000
# 3                                 354.350000
# 4                                 375.510000
# ...                                      ...
# 64459                               7.252381
# 64460                               6.443306
# 64461                               7.706000
# 64462                               5.548971
# 64463                               6.599165
#
#        Nuclei_Texture_Variance_RNA_3_00_256  \
# 0                                333.190000
# 1                                324.810000
# 2                                358.720000
# 3                                355.720000
# 4                                371.510000
# ...                                     ...
# 64459                              6.907879
# 64460                              6.660565
# 64461                              7.378235
# 64462                              5.338362
# 64463                              6.302489
#
#        Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                340.070000
# 1                                330.830000
# 2                                365.590000
# 3                                362.750000
# 4                                378.740000
# ...                                     ...
# 64459                              7.043682
# 64460                              6.791647
# 64461                              7.537031
# 64462                              5.446202
# 64463                              6.430033
#
#        Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                334.370000
# 1                                326.090000
# 2                                358.390000
# 3                                356.280000
# 4                                371.830000
# ...                                     ...
# 64459                              6.922703
# 64460                              6.668570
# 64461                              7.396785
# 64462                              5.354443
# 64463                              6.324221
#
#        Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                339.540000
# 1                                330.720000
# 2                                365.570000
# 3                                362.630000
# 4                                378.270000
# ...                                     ...
# 64459                              7.048655
# 64460                              6.780820
# 64461                              7.522082
# 64462                              5.438343
# 64463                              6.428646
#
#        Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                341.740000
# 1                                333.160000
# 2                                368.440000
# 3                                366.280000
# 4                                380.940000
# ...                                     ...
# 64459                              7.116519
# 64460                              6.862487
# 64461                              7.606077
# 64462                              5.490677
# 64463                              6.486092
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                348.540000
# 1                                340.850000
# 2                                376.590000
# 3                                373.050000
# 4                                387.840000
# ...                                     ...
# 64459                              7.300999
# 64460                              7.036637
# 64461                              7.795566
# 64462                              5.610534
# 64463                              6.656254
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                343.390000
# 1                                334.480000
# 2                                369.090000
# 3                                366.880000
# 4                                382.240000
# ...                                     ...
# 64459                              7.128542
# 64460                              6.880732
# 64461                              7.614485
# 64462                              5.494503
# 64463                              6.506301
#
#        Nuclei_Texture_Variance_RNA_5_03_256
# 0                                348.400000
# 1                                340.000000
# 2                                375.590000
# 3                                374.710000
# 4                                388.370000
# ...                                     ...
# 64459                              7.313541
# 64460                              6.992730
# 64461                              7.796514
# 64462                              5.608818
# 64463                              6.655908
#
# [64464 rows x 4766 columns]

# %% [markdown]
# ## Add metadata features

# %%
wc = wells.merge(compounds, on="Metadata_JCP2022", how="left")
target2_with_metadata = target2_features_imputed.merge(wc, on=["Metadata_Source", "Metadata_Plate", "Metadata_Well"], how="left")

# %%
target2_with_metadata
# Out:
#       Metadata_Source Metadata_Plate Metadata_Well Metadata_Batch  \
# 0            source_8       A1170384           A01             J1
# 1            source_8       A1170384           A02             J1
# 2            source_8       A1170384           A03             J1
# 3            source_8       A1170384           A04             J1
# 4            source_8       A1170384           A05             J1
# ...               ...            ...           ...            ...
# 64459       source_13   CP-CC9-R7-29           P20  20221120_Run6
# 64460       source_13   CP-CC9-R7-29           P21  20221120_Run6
# 64461       source_13   CP-CC9-R7-29           P22  20221120_Run6
# 64462       source_13   CP-CC9-R7-29           P23  20221120_Run6
# 64463       source_13   CP-CC9-R7-29           P24  20221120_Run6
#
#        Cells_AreaShape_Area  Cells_AreaShape_BoundingBoxArea  \
# 0               3683.200000                      7920.000000
# 1               3519.000000                      7427.500000
# 2               3551.500000                      7493.600000
# 3               3494.400000                      7360.200000
# 4               3625.800000                      7620.300000
# ...                     ...                              ...
# 64459           2735.141361                      5259.052356
# 64460           2492.848859                      4878.090779
# 64461           2701.863939                      5179.042455
# 64462           2755.432136                      5216.364957
# 64463           3092.713193                      5983.594328
#
#        Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                                570.710000
# 1                                574.880000
# 2                                548.580000
# 3                                561.720000
# 4                                552.490000
# ...                                     ...
# 64459                            679.311932
# 64460                            647.097909
# 64461                            653.885934
# 64462                            646.266520
# 64463                            667.466858
#
#        Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                565.870000
# 1                                586.630000
# 2                                547.250000
# 3                                580.460000
# 4                                576.340000
# ...                                     ...
# 64459                            572.702122
# 64460                            524.178232
# 64461                            579.227366
# 64462                            572.009049
# 64463                            583.646272
#
#        Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                482.460000
# 1                                488.560000
# 2                                463.350000
# 3                                477.120000
# 4                                466.990000
# ...                                     ...
# 64459                            608.692202
# 64460                            578.300856
# 64461                            584.200512
# 64462                            576.276940
# 64463                            591.395793
#
#        Cells_AreaShape_BoundingBoxMinimum_Y  ...  \
# 0                                478.170000  ...
# 1                                502.490000  ...
# 2                                461.680000  ...
# 3                                494.980000  ...
# 4                                489.870000  ...
# ...                                     ...  ...
# 64459                            502.787820  ...
# 64460                            458.030418  ...
# 64461                            509.318159  ...
# 64462                            501.680011  ...
# 64463                            509.997451  ...
#
#        Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                340.070000
# 1                                330.830000
# 2                                365.590000
# 3                                362.750000
# 4                                378.740000
# ...                                     ...
# 64459                              7.043682
# 64460                              6.791647
# 64461                              7.537031
# 64462                              5.446202
# 64463                              6.430033
#
#        Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                334.370000
# 1                                326.090000
# 2                                358.390000
# 3                                356.280000
# 4                                371.830000
# ...                                     ...
# 64459                              6.922703
# 64460                              6.668570
# 64461                              7.396785
# 64462                              5.354443
# 64463                              6.324221
#
#        Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                339.540000
# 1                                330.720000
# 2                                365.570000
# 3                                362.630000
# 4                                378.270000
# ...                                     ...
# 64459                              7.048655
# 64460                              6.780820
# 64461                              7.522082
# 64462                              5.438343
# 64463                              6.428646
#
#        Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                341.740000
# 1                                333.160000
# 2                                368.440000
# 3                                366.280000
# 4                                380.940000
# ...                                     ...
# 64459                              7.116519
# 64460                              6.862487
# 64461                              7.606077
# 64462                              5.490677
# 64463                              6.486092
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                348.540000
# 1                                340.850000
# 2                                376.590000
# 3                                373.050000
# 4                                387.840000
# ...                                     ...
# 64459                              7.300999
# 64460                              7.036637
# 64461                              7.795566
# 64462                              5.610534
# 64463                              6.656254
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                343.390000
# 1                                334.480000
# 2                                369.090000
# 3                                366.880000
# 4                                382.240000
# ...                                     ...
# 64459                              7.128542
# 64460                              6.880732
# 64461                              7.614485
# 64462                              5.494503
# 64463                              6.506301
#
#        Nuclei_Texture_Variance_RNA_5_03_256  Metadata_JCP2022  \
# 0                                348.400000    JCP2022_043547
# 1                                340.000000    JCP2022_050797
# 2                                375.590000    JCP2022_050997
# 3                                374.710000    JCP2022_108326
# 4                                388.370000    JCP2022_033924
# ...                                     ...               ...
# 64459                              7.313541    JCP2022_032357
# 64460                              6.992730    JCP2022_047545
# 64461                              7.796514    JCP2022_043099
# 64462                              5.608818    JCP2022_050516
# 64463                              6.655908    JCP2022_033924
#
#                  Metadata_InChIKey  \
# 0      KBPLFHHGFOOTCA-UHFFFAOYSA-N
# 1      LOUPRKONTZGTKE-UHFFFAOYSA-N
# 2      LPYXWGMUVRGUOY-UHFFFAOYSA-N
# 3      YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 4      IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# ...                            ...
# 64459  HSUGRBWQSSZJOP-UHFFFAOYSA-N
# 64460  KXBDTLQSDKGAEB-UHFFFAOYSA-N
# 64461  JZFPYUNJRRFVQU-UHFFFAOYSA-N
# 64462  LNFZRMDSZJCZTG-UHFFFAOYSA-N
# 64463  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
#
#                                           Metadata_InChI
# 0       InChI=1S/C8H18O/c1-2-3-4-5-6-7-8-9/h9H,2-8H2,1H3
# 1      InChI=1S/C20H24N2O2/c1-3-13-12-22-9-7-14(13)10...
# 2      InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/...
# 3      InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...
# 4                        InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# ...                                                  ...
# 64459  InChI=1S/C22H26N2O4S/c1-15(25)28-20-21(16-9-11...
# 64460  InChI=1S/C22H22FN5O3/c1-3-20(29)25-16-5-4-6-17...
# 64461  InChI=1S/C13H9F3N2O2/c14-13(15,16)8-3-1-4-9(7-...
# 64462  InChI=1S/C28H21F4N5O2/c1-15-4-6-19(35-27(39)37...
# 64463                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
#
# [64464 rows x 4769 columns]

# %% [markdown]
# ## Get standardized compound metadata

# %%
target2_compound_metadata = pd.read_csv(
    "../metadata/repurposing_samples_20200324_standardized.csv.gz",
    compression="gzip"
)
target2_compound_metadata = target2_compound_metadata[["InChIKey_standardized", "SMILES_standardized", "InChI_standardized", "pubchem_cid", "pert_iname"]].drop_duplicates()
target2_compound_metadata.pubchem_cid = pd.to_numeric(target2_compound_metadata.pubchem_cid, errors="coerce").fillna(0).astype(int)

print(target2_compound_metadata.shape)
target2_compound_metadata.head(3)
# Out:
# (6783, 5)
#          InChIKey_standardized                SMILES_standardized  \
# 0  VMWNQDUVQKEIOC-UHFFFAOYSA-N  CN1CCc2cccc3c2C1Cc1ccc(O)c(O)c1-3
# 4  HJORMJIFDVBMOB-UHFFFAOYSA-N    COc1ccc(C2CNC(=O)C2)cc1OC1CCCC1
# 7  KPYSYYIEGFHWSV-UHFFFAOYSA-N           NCC(CC(=O)O)c1ccc(Cl)cc1
#
#                                   InChI_standardized  pubchem_cid  \
# 0  InChI=1S/C17H17NO2/c1-18-8-7-10-3-2-4-12-15(10...         6005
# 4  InChI=1S/C16H21NO3/c1-19-14-7-6-11(12-9-16(18)...       448055
# 7  InChI=1S/C10H12ClNO2/c11-9-3-1-7(2-4-9)8(6-12)...      6918881
#
#             pert_iname
# 0  (R)-(-)-apomorphine
# 4     (R)-(-)-rolipram
# 7         (R)-baclofen

# %% [markdown]
# ## Add Broad TARGET2 and CLUE MOA info

# %%
target_moa = pd.read_csv(
    "https://raw.githubusercontent.com/jump-cellpainting/JUMP-MOA/master/JUMP-MOA_compound_metadata.tsv",
    sep="\t"
)
target_moa.pubchem_cid = pd.to_numeric(target_moa.pubchem_cid, errors="coerce").fillna(0).astype(int)

print(target_moa.shape)
target_moa.head(3)
# Out:
# (91, 8)
#              broad_sample                     InChIKey         pert_iname  \
# 0  BRD-K80935598-001-01-1  ZYVXTMKTGDARKR-UHFFFAOYSA-N              AZ191
# 1  BRD-K85776940-001-01-9  ODADKLYLWWCHNB-LDYBVBFYSA-N  delta-Tocotrienol
# 2  BRD-K25611237-001-02-1  QDBVSOZTVKXUES-UHFFFAOYSA-N              ML324
#
#    pubchem_cid                                   moa pert_type control_type  \
# 0     72716071                        DYRK inhibitor       trt          NaN
# 1      5282350                       HMGCR inhibitor       trt          NaN
# 2     44143209  histone lysine demethylase inhibitor       trt          NaN
#
#                                               smiles
# 0  COc1cc(ccc1Nc1nccc(n1)-c1cn(C)c2cnccc12)N1CCN(...
# 1  CC(C)=CCC\C(C)=C\CC\C(C)=C\CC[C@]1(C)CCc2cc(O)...
# 2         CN(C)CCCNC(=O)c1ccc(cc1)-c1cc(O)c2ncccc2c1

# %%
clue_moa = pd.read_csv(
    "../metadata/repurposing_drugs_20180907.txt",
    sep="\t"
)
clue_moa
# Out:
#                         pert_iname clinical_phase  \
# 0     [sar9,met(o2)11]-substance-p    Preclinical
# 1                        A-1070722    Preclinical
# 2                           A-1120    Preclinical
# 3                         A-317491    Preclinical
# 4                          A-33903        Phase 2
# ...                            ...            ...
# 6120                      8-M-PDOT    Preclinical
# 6121                    80841-78-7    Preclinical
# 6122               9-aminoacridine    Preclinical
# 6123           9-aminocamptothecin        Phase 2
# 6124   9-anthracenecarboxylic-acid    Preclinical
#
#                                      moa         target disease_area  \
# 0                  tachykinin antagonist          TACR1          NaN
# 1     glycogen synthase kinase inhibitor    GSK3A|GSK3B          NaN
# 2               retinoid receptor ligand           RBP4          NaN
# 3         purinergic receptor antagonist          P2RX3          NaN
# 4                                    NaN            NaN          NaN
# ...                                  ...            ...          ...
# 6120          melatonin receptor agonist  MTNR1A|MTNR1B          NaN
# 6121                                 NaN            NaN          NaN
# 6122                                 NaN            NaN          NaN
# 6123             topoisomerase inhibitor           TOP1          NaN
# 6124                                 NaN     ANO1|CLCN1          NaN
#
#      indication
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 6120        NaN
# 6121        NaN
# 6122        NaN
# 6123        NaN
# 6124        NaN
#
# [6125 rows x 6 columns]

# %% [markdown]
# ## Merge and deal with overlapping columns

# %%
# first create empty pert_iname df, then merge in metadata
df = pd.DataFrame(index=target2_compound_metadata["pert_iname"].str.lower())

target_moa["pert_iname"] = target_moa["pert_iname"].str.lower()
target_moa.set_index("pert_iname", drop=False, inplace=True, verify_integrity=True)

clue_moa["pert_iname"] = clue_moa["pert_iname"].str.lower()
clue_moa.set_index("pert_iname", drop=False, inplace=True, verify_integrity=True)

# %%
df_target = df.merge(target_moa, how="left", right_index=True, left_index=True)
df_target_clue = df_target.merge(clue_moa, how="left", right_index=True, left_index=True)

def merge_moa(row):
    moa_x = row["moa_x"]
    moa_y = row["moa_y"]

    if pd.isna(moa_x) and pd.isna(moa_y):
        return np.nan

    moas = set([moa for moa in [moa_x, moa_y] if not pd.isna(moa)])
    return "|".join(moas) if moas else np.nan

df_target_clue["moa"] = df_target_clue.apply(merge_moa, axis=1)
df_target_clue = df_target_clue[[
    "clinical_phase",
    "target",
    "disease_area",
    "indication",
    "moa",
]]

# Remove all NaN-rows for more efficient downstream 
df_target_clue = df_target_clue.dropna(how="all")

# Add index back as column so we can merge on it
df_target_clue.reset_index(inplace=True)

df_target_clue = df_target_clue.drop_duplicates()

df_target_clue
# Out:
#                             pert_iname   clinical_phase  \
# 0                            1,12-besm          Phase 2
# 1     1,2,3,4,5,6-hexabromocyclohexane      Preclinical
# 2        1,3-dipropyl-8-phenylxanthine      Preclinical
# 3                       1,4-butanediol          Phase 1
# 4            1,5-dicaffeoylquinic-acid          Phase 1
# ...                                ...              ...
# 5924                       zotarolimus         Launched
# 5925                          zotepine         Launched
# 5926                      zoxazolamine          Phase 2
# 5927                          zstk-474  Phase 1/Phase 2
# 5928                    zuclopenthixol         Launched
#
#                                                  target          disease_area  \
# 0                                                   NaN                   NaN
# 1                                                  JAK2                   NaN
# 2                                                   NaN                   NaN
# 3                                MAN1B1|PLA2G2A|PLA2G2E                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 5924                                             FKBP1A            cardiology
# 5925  ADRA2B|DRD2|DRD3|DRD4|HRH1|HTR1A|HTR1B|HTR1D|H...  neurology/psychiatry
# 5926                                                NaN                   NaN
# 5927                               PIK3CB|PIK3CD|PIK3CG                   NaN
# 5928            ADRA1A|ADRA2A|DRD1|DRD2|DRD5|HRH1|HTR2A  neurology/psychiatry
#
#                           indication  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 5924      coronary artery restenosis
# 5925                   schizophrenia
# 5926                             NaN
# 5927                             NaN
# 5928  schizophrenia|bipolar disorder
#
#                                                     moa
# 0                      polyamine biosynthesis inhibitor
# 1                                         JAK inhibitor
# 2                         adenosine receptor antagonist
# 3     benzodiazepine receptor agonist|gamma hydroxyb...
# 4                                                   NaN
# ...                                                 ...
# 5924                                     mTOR inhibitor
# 5925  dopamine receptor antagonist|serotonin recepto...
# 5926                                        myorelaxant
# 5927                                     PI3K inhibitor
# 5928                       dopamine receptor antagonist
#
# [5922 rows x 6 columns]

# %% [markdown]
# ## Merge into used compounds

# %%
target2_compound_metadata["pert_iname"] = target2_compound_metadata["pert_iname"].str.lower()
target2_compound_metadata = target2_compound_metadata.drop_duplicates()
target2_compound_metadata = target2_compound_metadata.merge(
    df_target_clue,
    how="left",
    left_on="pert_iname",
    right_on="pert_iname"
)

# Have to add 'Metadata' here so that PyCytoMiner doesn't drop the cols later
target2_compound_metadata.columns = [f"Metadata_{col}" if "Metadata_" not in col else col for col in target2_compound_metadata.columns]

target2_compound_metadata
# Out:
#      Metadata_InChIKey_standardized  \
# 0       VMWNQDUVQKEIOC-UHFFFAOYSA-N
# 1       HJORMJIFDVBMOB-UHFFFAOYSA-N
# 2       KPYSYYIEGFHWSV-UHFFFAOYSA-N
# 3       HJORMJIFDVBMOB-UHFFFAOYSA-N
# 4       OUPXSLGGCPUZJJ-UHFFFAOYSA-N
# ...                             ...
# 6778    YGCODSQDUUUKIV-UHFFFAOYSA-N
# 6779    QZWYXEBIQWJXAR-UHFFFAOYSA-N
# 6780    HGVNLRPZOWWDKD-UHFFFAOYSA-N
# 6781    WFPIAZLQTJBIFN-UHFFFAOYSA-N
# 6782    HARRKNSQXBRBGZ-UHFFFAOYSA-N
#
#                            Metadata_SMILES_standardized  \
# 0                     CN1CCc2cccc3c2C1Cc1ccc(O)c(O)c1-3
# 1                       COc1ccc(C2CNC(=O)C2)cc1OC1CCCC1
# 2                              NCC(CC(=O)O)c1ccc(Cl)cc1
# 3                       COc1ccc(C2CNC(=O)C2)cc1OC1CCCC1
# 4     CC(C)CC(NC(=O)CN(C)C(=O)C(Cc1ccccc1)NC(=O)C(Cc...
# ...                                                 ...
# 6778                             N=c1[nH]c2cc(Cl)ccc2o1
# 6779                     O=C1N=C2C=CC=CN2C12Cc1ccccc1C2
# 6780    FC(F)c1nc2ccccc2n1-c1nc(N2CCOCC2)nc(N2CCOCC2)n1
# 6781          OCCN1CCN(CCC=C2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 6782  CC1(O)CCC2C(CCC3C2CCC2(C)C(C(=O)Cn4cc(C#N)cn4)...
#
#                             Metadata_InChI_standardized  Metadata_pubchem_cid  \
# 0     InChI=1S/C17H17NO2/c1-18-8-7-10-3-2-4-12-15(10...                  6005
# 1     InChI=1S/C16H21NO3/c1-19-14-7-6-11(12-9-16(18)...                448055
# 2     InChI=1S/C10H12ClNO2/c11-9-3-1-7(2-4-9)8(6-12)...               6918881
# 3     InChI=1S/C16H21NO3/c1-19-14-7-6-11(12-9-16(18)...                158758
# 4     InChI=1S/C64H100N18O15S/c1-38(2)34-46(57(89)74...                163829
# ...                                                 ...                   ...
# 6778  InChI=1S/C7H5ClN2O/c8-4-1-2-6-5(3-4)10-7(9)11-...                  6103
# 6779  InChI=1S/C15H12N2O/c18-14-15(17-8-4-3-7-13(17)...              10220323
# 6780  InChI=1S/C19H21F2N7O2/c20-15(21)16-22-13-3-1-2...              11647372
# 6781  InChI=1S/C22H25ClN2OS/c23-17-7-8-22-20(16-17)1...               5311507
# 6782  InChI=1S/C25H35N3O2/c1-24(30)9-7-18-17(11-24)3...              86294073
#
#                Metadata_pert_iname Metadata_clinical_phase  \
# 0              (r)-(-)-apomorphine                     NaN
# 1                 (r)-(-)-rolipram                     NaN
# 2                     (r)-baclofen                     NaN
# 3                 (s)-(+)-rolipram                     NaN
# 4     [sar9,met(o2)11]-substance-p             Preclinical
# ...                            ...                     ...
# 6778                  zoxazolamine                 Phase 2
# 6779                      zset1446                     NaN
# 6780                      zstk-474         Phase 1/Phase 2
# 6781                zuclopenthixol                Launched
# 6782                    zuranolone                     NaN
#
#                               Metadata_target Metadata_disease_area  \
# 0                                         NaN                   NaN
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                       TACR1                   NaN
# ...                                       ...                   ...
# 6778                                      NaN                   NaN
# 6779                                      NaN                   NaN
# 6780                     PIK3CB|PIK3CD|PIK3CG                   NaN
# 6781  ADRA1A|ADRA2A|DRD1|DRD2|DRD5|HRH1|HTR2A  neurology/psychiatry
# 6782                                      NaN                   NaN
#
#                  Metadata_indication                  Metadata_moa
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN         tachykinin antagonist
# ...                              ...                           ...
# 6778                             NaN                   myorelaxant
# 6779                             NaN                           NaN
# 6780                             NaN                PI3K inhibitor
# 6781  schizophrenia|bipolar disorder  dopamine receptor antagonist
# 6782                             NaN                           NaN
#
# [6783 rows x 10 columns]

# %%
target2_with_metadata
# Out:
#       Metadata_Source Metadata_Plate Metadata_Well Metadata_Batch  \
# 0            source_8       A1170384           A01             J1
# 1            source_8       A1170384           A02             J1
# 2            source_8       A1170384           A03             J1
# 3            source_8       A1170384           A04             J1
# 4            source_8       A1170384           A05             J1
# ...               ...            ...           ...            ...
# 64459       source_13   CP-CC9-R7-29           P20  20221120_Run6
# 64460       source_13   CP-CC9-R7-29           P21  20221120_Run6
# 64461       source_13   CP-CC9-R7-29           P22  20221120_Run6
# 64462       source_13   CP-CC9-R7-29           P23  20221120_Run6
# 64463       source_13   CP-CC9-R7-29           P24  20221120_Run6
#
#        Cells_AreaShape_Area  Cells_AreaShape_BoundingBoxArea  \
# 0               3683.200000                      7920.000000
# 1               3519.000000                      7427.500000
# 2               3551.500000                      7493.600000
# 3               3494.400000                      7360.200000
# 4               3625.800000                      7620.300000
# ...                     ...                              ...
# 64459           2735.141361                      5259.052356
# 64460           2492.848859                      4878.090779
# 64461           2701.863939                      5179.042455
# 64462           2755.432136                      5216.364957
# 64463           3092.713193                      5983.594328
#
#        Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                                570.710000
# 1                                574.880000
# 2                                548.580000
# 3                                561.720000
# 4                                552.490000
# ...                                     ...
# 64459                            679.311932
# 64460                            647.097909
# 64461                            653.885934
# 64462                            646.266520
# 64463                            667.466858
#
#        Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                565.870000
# 1                                586.630000
# 2                                547.250000
# 3                                580.460000
# 4                                576.340000
# ...                                     ...
# 64459                            572.702122
# 64460                            524.178232
# 64461                            579.227366
# 64462                            572.009049
# 64463                            583.646272
#
#        Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                482.460000
# 1                                488.560000
# 2                                463.350000
# 3                                477.120000
# 4                                466.990000
# ...                                     ...
# 64459                            608.692202
# 64460                            578.300856
# 64461                            584.200512
# 64462                            576.276940
# 64463                            591.395793
#
#        Cells_AreaShape_BoundingBoxMinimum_Y  ...  \
# 0                                478.170000  ...
# 1                                502.490000  ...
# 2                                461.680000  ...
# 3                                494.980000  ...
# 4                                489.870000  ...
# ...                                     ...  ...
# 64459                            502.787820  ...
# 64460                            458.030418  ...
# 64461                            509.318159  ...
# 64462                            501.680011  ...
# 64463                            509.997451  ...
#
#        Nuclei_Texture_Variance_RNA_3_01_256  \
# 0                                340.070000
# 1                                330.830000
# 2                                365.590000
# 3                                362.750000
# 4                                378.740000
# ...                                     ...
# 64459                              7.043682
# 64460                              6.791647
# 64461                              7.537031
# 64462                              5.446202
# 64463                              6.430033
#
#        Nuclei_Texture_Variance_RNA_3_02_256  \
# 0                                334.370000
# 1                                326.090000
# 2                                358.390000
# 3                                356.280000
# 4                                371.830000
# ...                                     ...
# 64459                              6.922703
# 64460                              6.668570
# 64461                              7.396785
# 64462                              5.354443
# 64463                              6.324221
#
#        Nuclei_Texture_Variance_RNA_3_03_256  \
# 0                                339.540000
# 1                                330.720000
# 2                                365.570000
# 3                                362.630000
# 4                                378.270000
# ...                                     ...
# 64459                              7.048655
# 64460                              6.780820
# 64461                              7.522082
# 64462                              5.438343
# 64463                              6.428646
#
#        Nuclei_Texture_Variance_RNA_5_00_256  \
# 0                                341.740000
# 1                                333.160000
# 2                                368.440000
# 3                                366.280000
# 4                                380.940000
# ...                                     ...
# 64459                              7.116519
# 64460                              6.862487
# 64461                              7.606077
# 64462                              5.490677
# 64463                              6.486092
#
#        Nuclei_Texture_Variance_RNA_5_01_256  \
# 0                                348.540000
# 1                                340.850000
# 2                                376.590000
# 3                                373.050000
# 4                                387.840000
# ...                                     ...
# 64459                              7.300999
# 64460                              7.036637
# 64461                              7.795566
# 64462                              5.610534
# 64463                              6.656254
#
#        Nuclei_Texture_Variance_RNA_5_02_256  \
# 0                                343.390000
# 1                                334.480000
# 2                                369.090000
# 3                                366.880000
# 4                                382.240000
# ...                                     ...
# 64459                              7.128542
# 64460                              6.880732
# 64461                              7.614485
# 64462                              5.494503
# 64463                              6.506301
#
#        Nuclei_Texture_Variance_RNA_5_03_256  Metadata_JCP2022  \
# 0                                348.400000    JCP2022_043547
# 1                                340.000000    JCP2022_050797
# 2                                375.590000    JCP2022_050997
# 3                                374.710000    JCP2022_108326
# 4                                388.370000    JCP2022_033924
# ...                                     ...               ...
# 64459                              7.313541    JCP2022_032357
# 64460                              6.992730    JCP2022_047545
# 64461                              7.796514    JCP2022_043099
# 64462                              5.608818    JCP2022_050516
# 64463                              6.655908    JCP2022_033924
#
#                  Metadata_InChIKey  \
# 0      KBPLFHHGFOOTCA-UHFFFAOYSA-N
# 1      LOUPRKONTZGTKE-UHFFFAOYSA-N
# 2      LPYXWGMUVRGUOY-UHFFFAOYSA-N
# 3      YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 4      IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# ...                            ...
# 64459  HSUGRBWQSSZJOP-UHFFFAOYSA-N
# 64460  KXBDTLQSDKGAEB-UHFFFAOYSA-N
# 64461  JZFPYUNJRRFVQU-UHFFFAOYSA-N
# 64462  LNFZRMDSZJCZTG-UHFFFAOYSA-N
# 64463  IAZDPXIOMUYVGZ-UHFFFAOYSA-N
#
#                                           Metadata_InChI
# 0       InChI=1S/C8H18O/c1-2-3-4-5-6-7-8-9/h9H,2-8H2,1H3
# 1      InChI=1S/C20H24N2O2/c1-3-13-12-22-9-7-14(13)10...
# 2      InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/...
# 3      InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...
# 4                        InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# ...                                                  ...
# 64459  InChI=1S/C22H26N2O4S/c1-15(25)28-20-21(16-9-11...
# 64460  InChI=1S/C22H22FN5O3/c1-3-20(29)25-16-5-4-6-17...
# 64461  InChI=1S/C13H9F3N2O2/c14-13(15,16)8-3-1-4-9(7-...
# 64462  InChI=1S/C28H21F4N5O2/c1-15-4-6-19(35-27(39)37...
# 64463                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
#
# [64464 rows x 4769 columns]

# %%
target2_complete = target2_with_metadata.merge(
    target2_compound_metadata,
    left_on="Metadata_InChIKey",
    right_on="Metadata_InChIKey_standardized",
    how="left"
).drop_duplicates(subset=["Metadata_Source", "Metadata_Plate", "Metadata_Well"])

target2_complete
# Out:
#       Metadata_Source Metadata_Plate Metadata_Well Metadata_Batch  \
# 0            source_8       A1170384           A01             J1
# 1            source_8       A1170384           A02             J1
# 3            source_8       A1170384           A03             J1
# 4            source_8       A1170384           A04             J1
# 6            source_8       A1170384           A05             J1
# ...               ...            ...           ...            ...
# 67313       source_13   CP-CC9-R7-29           P20  20221120_Run6
# 67314       source_13   CP-CC9-R7-29           P21  20221120_Run6
# 67315       source_13   CP-CC9-R7-29           P22  20221120_Run6
# 67316       source_13   CP-CC9-R7-29           P23  20221120_Run6
# 67317       source_13   CP-CC9-R7-29           P24  20221120_Run6
#
#        Cells_AreaShape_Area  Cells_AreaShape_BoundingBoxArea  \
# 0               3683.200000                      7920.000000
# 1               3519.000000                      7427.500000
# 3               3551.500000                      7493.600000
# 4               3494.400000                      7360.200000
# 6               3625.800000                      7620.300000
# ...                     ...                              ...
# 67313           2735.141361                      5259.052356
# 67314           2492.848859                      4878.090779
# 67315           2701.863939                      5179.042455
# 67316           2755.432136                      5216.364957
# 67317           3092.713193                      5983.594328
#
#        Cells_AreaShape_BoundingBoxMaximum_X  \
# 0                                570.710000
# 1                                574.880000
# 3                                548.580000
# 4                                561.720000
# 6                                552.490000
# ...                                     ...
# 67313                            679.311932
# 67314                            647.097909
# 67315                            653.885934
# 67316                            646.266520
# 67317                            667.466858
#
#        Cells_AreaShape_BoundingBoxMaximum_Y  \
# 0                                565.870000
# 1                                586.630000
# 3                                547.250000
# 4                                580.460000
# 6                                576.340000
# ...                                     ...
# 67313                            572.702122
# 67314                            524.178232
# 67315                            579.227366
# 67316                            572.009049
# 67317                            583.646272
#
#        Cells_AreaShape_BoundingBoxMinimum_X  \
# 0                                482.460000
# 1                                488.560000
# 3                                463.350000
# 4                                477.120000
# 6                                466.990000
# ...                                     ...
# 67313                            608.692202
# 67314                            578.300856
# 67315                            584.200512
# 67316                            576.276940
# 67317                            591.395793
#
#        Cells_AreaShape_BoundingBoxMinimum_Y  ...  \
# 0                                478.170000  ...
# 1                                502.490000  ...
# 3                                461.680000  ...
# 4                                494.980000  ...
# 6                                489.870000  ...
# ...                                     ...  ...
# 67313                            502.787820  ...
# 67314                            458.030418  ...
# 67315                            509.318159  ...
# 67316                            501.680011  ...
# 67317                            509.997451  ...
#
#        Metadata_InChIKey_standardized  \
# 0         KBPLFHHGFOOTCA-UHFFFAOYSA-N
# 1         LOUPRKONTZGTKE-UHFFFAOYSA-N
# 3         LPYXWGMUVRGUOY-UHFFFAOYSA-N
# 4         YGSDEFSMJLZEOE-UHFFFAOYSA-N
# 6         IAZDPXIOMUYVGZ-UHFFFAOYSA-N
# ...                               ...
# 67313     HSUGRBWQSSZJOP-UHFFFAOYSA-N
# 67314     KXBDTLQSDKGAEB-UHFFFAOYSA-N
# 67315     JZFPYUNJRRFVQU-UHFFFAOYSA-N
# 67316     LNFZRMDSZJCZTG-UHFFFAOYSA-N
# 67317     IAZDPXIOMUYVGZ-UHFFFAOYSA-N
#
#                             Metadata_SMILES_standardized  \
# 0                                              CCCCCCCCO
# 1                  C=CC1CN2CCC1CC2C(O)c1ccnc2ccc(OC)cc12
# 3                                   OCC(O)c1oc(O)c(O)c1O
# 4                                        O=C(O)c1ccccc1O
# 6                                           C[S+](C)[O-]
# ...                                                  ...
# 67313    COc1ccc(C2Sc3ccccc3N(CCN(C)C)C(=O)C2OC(C)=O)cc1
# 67314  C=CC(=O)Nc1cccc(N=c2[nH]c(=Nc3ccc(OCCOC)cc3)[n...
# 67315              O=C(O)c1ccc[nH]c1=Nc1cccc(C(F)(F)F)c1
# 67316  Cc1ccc(NC(=O)Nc2cc(C(F)(F)F)ccc2F)cc1Nc1ccc2c(...
# 67317                                       C[S+](C)[O-]
#
#                              Metadata_InChI_standardized  \
# 0       InChI=1S/C8H18O/c1-2-3-4-5-6-7-8-9/h9H,2-8H2,1H3
# 1      InChI=1S/C20H24N2O2/c1-3-13-12-22-9-7-14(13)10...
# 3      InChI=1S/C6H8O6/c7-1-2(8)5-3(9)4(10)6(11)12-5/...
# 4      InChI=1S/C7H6O3/c8-6-4-2-1-3-5(6)7(9)10/h1-4,8...
# 6                        InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
# ...                                                  ...
# 67313  InChI=1S/C22H26N2O4S/c1-15(25)28-20-21(16-9-11...
# 67314  InChI=1S/C22H22FN5O3/c1-3-20(29)25-16-5-4-6-17...
# 67315  InChI=1S/C13H9F3N2O2/c14-13(15,16)8-3-1-4-9(7-...
# 67316  InChI=1S/C28H21F4N5O2/c1-15-4-6-19(35-27(39)37...
# 67317                    InChI=1S/C2H6OS/c1-4(2)3/h1-2H3
#
#        Metadata_pubchem_cid    Metadata_pert_iname  Metadata_clinical_phase  \
# 0                       957              1-octanol                  Phase 2
# 1                    441074              quinidine                 Launched
# 3                         0          ascorbic-acid                 Launched
# 4                  53629521  bismuth-subsalicylate                 Launched
# 6                  21584481                   dmso              Preclinical
# ...                     ...                    ...                      ...
# 67313                 39186              diltiazem                 Launched
# 67314              59174488                avl-292                  Phase 2
# 67315                  4488          niflumic-acid                 Launched
# 67316              59397065               gnf-5837              Preclinical
# 67317              21584481                   dmso              Preclinical
#
#                                          Metadata_target  \
# 0      GJA1|GJA10|GJA3|GJA4|GJA5|GJA8|GJA9|GJB1|GJB2|...
# 1      KCNA5|KCNA7|KCNH1|KCNH2|KCNH5|KCNK1|KCNK6|SCN5...
# 3      ALKBH2|ALKBH3|BBOX1|DBH|EGLN1|EGLN2|EGLN3|KDM5...
# 4                                                    NaN
# 6                                                    NaN
# ...                                                  ...
# 67313        CACNA1C|CACNA1S|CACNA2D1|CACNG1|HTR3A|KCNA5
# 67314                                           BTK|YES1
# 67315  ANO1|CLCN1|CLCNKA|CLCNKB|KCNQ1|PLA2G1B|PLA2G4A...
# 67316                                  NTRK1|NTRK2|NTRK3
# 67317                                                NaN
#
#                    Metadata_disease_area  \
# 0                                    NaN
# 1          infectious disease|cardiology
# 3                          endocrinology
# 4                       gastroenterology
# 6                                    NaN
# ...                                  ...
# 67313                         cardiology
# 67314                                NaN
# 67315  rheumatology|neurology/psychiatry
# 67316                                NaN
# 67317                                NaN
#
#                                      Metadata_indication  \
# 0                                                    NaN
# 1      malaria|atrial fibrillation (AF)|ventricular a...
# 3                                                 scurvy
# 4                                               diarrhea
# 6                                                    NaN
# ...                                                  ...
# 67313                       hypertension|angina pectoris
# 67314                                                NaN
# 67315                             joint pain|muscle pain
# 67316                                                NaN
# 67317                                                NaN
#
#                                    Metadata_moa
# 0                                           NaN
# 1                        sodium channel blocker
# 3                                   antioxidant
# 4                                       antacid
# 6                               control vehicle
# ...                                         ...
# 67313                   calcium channel blocker
# 67314  Bruton's tyrosine kinase (BTK) inhibitor
# 67315                  cyclooxygenase inhibitor
# 67316          growth factor receptor inhibitor
# 67317                           control vehicle
#
# [64464 rows x 4779 columns]

# %% [markdown]
# ## Merge in microscope config

# %%
microscope_config = pd.read_csv("../metadata/microscope_config.csv")
microscope_config["Metadata_Source"] = [f"source_{s}" for s in microscope_config.Metadata_Source.unique()]
microscope_config
# Out:
#    Metadata_Source    Metadata_Microscope_Name Metadata_Widefield_vs_Confocal  \
# 0         source_1                Opera Phenix                      Widefield
# 1         source_2                      CV8000                       Confocal
# 2         source_3                Opera Phenix                      Widefield
# 3         source_4                Opera Phenix                      Widefield
# 4         source_5                      CV8000                       Confocal
# 5         source_6                      CV8000                       Confocal
# 6         source_7                      CV7000                       Confocal
# 7         source_8  ImageXpress Micro Confocal                       Confocal
# 8         source_9                Opera Phenix                      Widefield
# 9        source_10                      CV8000                       Confocal
# 10       source_11                    Operetta                      Widefield
# 11       source_13                      CV7000                       Confocal
# 12       source_15                Opera Phenix                      Widefield
#
#    Metadata_Excitation_Type  Metadata_Objective_NA  \
# 0                     Laser                   1.00
# 1                     Laser                   1.00
# 2                     Laser                   1.00
# 3                     Laser                   1.00
# 4                     Laser                   0.75
# 5                     Laser                   0.75
# 6                     Laser                   0.75
# 7                       LED                   0.75
# 8                     Laser                   0.80
# 9                     Laser                   0.75
# 10                      LED                   1.00
# 11                    Laser                   0.75
# 12                    Laser                   0.40
#
#     Metadata_N_Brightfield_Planes_Min  Metadata_N_Brightfield_Planes_Max  \
# 0                                   1                                  1
# 1                                   3                                  3
# 2                                   0                                  3
# 3                                   3                                  3
# 4                                   3                                  3
# 5                                   3                                  3
# 6                                   0                                  0
# 7                                   0                                  0
# 8                                   0                                  0
# 9                                   3                                  3
# 10                                  1                                  1
# 11                                  0                                  0
# 12                                  3                                  3
#
#     Metadata_Distance_Between_Z_Microns  Metadata_Sites_Per_Well  \
# 0                                   NaN                        4
# 1                                   8.0                        6
# 2                                   5.0                        9
# 3                                   5.0                        9
# 4                                   5.0                        9
# 5                                   5.0                        9
# 6                                   NaN                        9
# 7                                   3.0                        9
# 8                                   NaN                        4
# 9                                   5.0                        6
# 10                                  NaN                        9
# 11                                  NaN                        9
# 12                                  5.0                        9
#
#    Metadata_Filter_Configuration
# 0                              H
# 1                              A
# 2                              B
# 3                              B
# 4                              C
# 5                              A
# 6                              D
# 7                              E
# 8                              H
# 9                              A
# 10                             F
# 11                             D
# 12                             G

# %%
target2_complete = target2_complete.merge(
    microscope_config,
    left_on="Metadata_Source",
    right_on="Metadata_Source",
    how="left"
)

# %% [markdown]
# ## Save to disk

# %%
target2_complete.to_parquet("../data/target2_wellres_featuresimputed_druginfoadded.parquet")
